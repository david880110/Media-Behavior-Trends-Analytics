# %%
# Import dependencies
import sqlite3
import pandas as pd
import numpy as np
from numpy import nan

# %%
# Connect to database
conn = sqlite3.connect('database.sqlite')

# %%
# Read sqlite query results into a pandas DataFrame
test_df = pd.read_sql_query("""
SELECT 
*
FROM east_central_table

union

SELECT 
*
FROM north_east_table

union

SELECT 
*
FROM pacific_table

union

SELECT 
*
FROM south_table

union

SELECT 
*
FROM south_east_table

union

SELECT 
*
FROM south_west_table

union

SELECT 
*
FROM west_central_table

""",conn)

test_df
# Out:
#       index                                           category  gender    age  \
# 0         0                                             totals    Male  18-24
# 1         0                                             totals    Male  18-24
# 2         0                                             totals    Male  18-24
# 3         0                                             totals    Male  18-24
# 4         0                                             totals    Male  18-24
# 5         1                                             totals    Male  25-34
# 6         1                                             totals    Male  25-34
# 7         1                                             totals    Male  25-34
# 8         1                                             totals    Male  25-34
# 9         1                                             totals    Male  25-34
# 10        1                                             totals    Male  25-34
# 11        2                                             totals    Male  35-44
# 12        2                                             totals    Male  35-44
# 13        2                                             totals    Male  35-44
# 14        2                                             totals    Male  35-44
# 15        2                                             totals    Male  35-44
# 16        2                                             totals    Male  35-44
# 17        3                                             totals    Male  45-54
# 18        3                                             totals    Male  45-54
# 19        3                                             totals    Male  45-54
# 20        3                                             totals    Male  45-54
# 21        3                                             totals    Male  45-54
# 22        3                                             totals    Male  45-54
# 23        4                                             totals    Male    55+
# 24        4                                             totals    Male    55+
# 25        4                                             totals    Male    55+
# 26        4                                             totals    Male    55+
# 27        4                                             totals    Male    55+
# 28        4                                             totals    Male    55+
# 29        5                                             totals  Female  18-24
# ...     ...                                                ...     ...    ...
# 3767   1090                                       tablet_owner    Male  18-24
# 3768   1091                                       tablet_owner    Male  25-34
# 3769   1092                                       tablet_owner    Male  35-44
# 3770   1093                                       tablet_owner    Male  45-54
# 3771   1094                                       tablet_owner    Male    55+
# 3772   1095                                       tablet_owner  Female  18-24
# 3773   1096                                       tablet_owner  Female  25-34
# 3774   1097                                       tablet_owner  Female  35-44
# 3775   1098                                       tablet_owner  Female  45-54
# 3776   1099                                       tablet_owner  Female    55+
# 3777   1100  all_live_theater/concerts/dance-attended_last_...    Male  18-24
# 3778   1101  all_live_theater/concerts/dance-attended_last_...    Male  25-34
# 3779   1102  all_live_theater/concerts/dance-attended_last_...    Male  35-44
# 3780   1103  all_live_theater/concerts/dance-attended_last_...    Male  45-54
# 3781   1104  all_live_theater/concerts/dance-attended_last_...    Male    55+
# 3782   1105  all_live_theater/concerts/dance-attended_last_...  Female  18-24
# 3783   1106  all_live_theater/concerts/dance-attended_last_...  Female  25-34
# 3784   1107  all_live_theater/concerts/dance-attended_last_...  Female  35-44
# 3785   1108  all_live_theater/concerts/dance-attended_last_...  Female  45-54
# 3786   1109  all_live_theater/concerts/dance-attended_last_...  Female    55+
# 3787   1110                   social_media_[social_media_user]    Male  18-24
# 3788   1111                   social_media_[social_media_user]    Male  25-34
# 3789   1112                   social_media_[social_media_user]    Male  35-44
# 3790   1113                   social_media_[social_media_user]    Male  45-54
# 3791   1114                   social_media_[social_media_user]    Male    55+
# 3792   1115                   social_media_[social_media_user]  Female  18-24
# 3793   1116                   social_media_[social_media_user]  Female  25-34
# 3794   1117                   social_media_[social_media_user]  Female  35-44
# 3795   1118                   social_media_[social_media_user]  Female  45-54
# 3796   1119                   social_media_[social_media_user]  Female    55+
#
#       year      division  population
# 0     2013  east_central          27
# 1     2013  east_central          31
# 2     2013  east_central          55
# 3     2013  east_central          78
# 4     2014  east_central          54
# 5     2013  east_central          51
# 6     2013  east_central          72
# 7     2013  east_central          78
# 8     2013  east_central          89
# 9     2013  east_central         160
# 10    2014  east_central          70
# 11    2013  east_central          71
# 12    2013  east_central          76
# 13    2013  east_central          85
# 14    2013  east_central         111
# 15    2013  east_central         198
# 16    2014  east_central          98
# 17    2013  east_central          64
# 18    2013  east_central          74
# 19    2013  east_central          87
# 20    2013  east_central         112
# 21    2013  east_central         170
# 22    2014  east_central         114
# 23    2013  east_central          78
# 24    2013  east_central         109
# 25    2013  east_central         141
# 26    2013  east_central         145
# 27    2013  east_central         247
# 28    2014  east_central         183
# 29    2013  east_central          40
# ...    ...           ...         ...
# 3767  2017  east_central           8
# 3768  2017  east_central          28
# 3769  2017  east_central          30
# 3770  2017  east_central          14
# 3771  2017  east_central          19
# 3772  2017  east_central          13
# 3773  2017  east_central          36
# 3774  2017  east_central          25
# 3775  2017  east_central          23
# 3776  2017  east_central          14
# 3777  2017  east_central          18
# 3778  2017  east_central          29
# 3779  2017  east_central          29
# 3780  2017  east_central          16
# 3781  2017  east_central           9
# 3782  2017  east_central          13
# 3783  2017  east_central          28
# 3784  2017  east_central          19
# 3785  2017  east_central          17
# 3786  2017  east_central          14
# 3787  2017  east_central          34
# 3788  2017  east_central          59
# 3789  2017  east_central          49
# 3790  2017  east_central          25
# 3791  2017  east_central          31
# 3792  2017  east_central          23
# 3793  2017  east_central          52
# 3794  2017  east_central          35
# 3795  2017  east_central          32
# 3796  2017  east_central          33
#
# [3797 rows x 7 columns]

# %%
# Save clean data to csv
test_df.to_csv('test_data/test_data.csv', index = False)
