# %%
# Ddd dependencies
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy import Column, Integer, String, Float, Date

# %%
# Load csv files
dmgp_data = 'raw_data/PEP_2017_PEPAGESEX_with_ann.csv'

# %%
# Read Data File and store into Pandas Data Frames
dmgp_df = pd.read_csv(dmgp_data)

# %%
dmgp_df.head()
# Out:
#            GEO.id GEO.id2           GEO.display-label  \
# 0              Id     Id2                   Geography
# 1  0500000US06001   06001  Alameda County, California
# 2  0500000US06003   06003   Alpine County, California
# 3  0500000US06005   06005   Amador County, California
# 4  0500000US06007   06007    Butte County, California
#
#                           cen42010sex0_age999  \
# 0  April 1, 2010 - Census - Both Sexes; Total
# 1                                     1510271
# 2                                        1175
# 3                                       38091
# 4                                      220000
#
#                     cen42010sex1_age999  \
# 0  April 1, 2010 - Census - Male; Total
# 1                                740573
# 2                                   606
# 3                                 20749
# 4                                108931
#
#                       cen42010sex2_age999  \
# 0  April 1, 2010 - Census - Female; Total
# 1                                  769698
# 2                                     569
# 3                                   17342
# 4                                  111069
#
#                                  est42010sex0_age999  \
# 0  April 1, 2010 - Estimates Base - Both Sexes; T...
# 1                                            1510261
# 2                                               1175
# 3                                              38091
# 4                                             220002
#
#                             est42010sex1_age999  \
# 0  April 1, 2010 - Estimates Base - Male; Total
# 1                                        740570
# 2                                           606
# 3                                         20749
# 4                                        108932
#
#                               est42010sex2_age999  \
# 0  April 1, 2010 - Estimates Base - Female; Total
# 1                                          769691
# 2                                             569
# 3                                           17342
# 4                                          111070
#
#                                  est72010sex0_age999  \
# 0  Population Estimate (as of July 1) - 2010 - Bo...
# 1                                            1513402
# 2                                               1161
# 3                                              37884
# 4                                             219957
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                  est72014sex2_medage  \
# 0  Population Estimate (as of July 1) - 2014 - Fe...
# 1                                               38.1
# 2                                               47.8
# 3                                               53.1
# 4                                               38.9
#
#                                  est72015sex0_medage  \
# 0  Population Estimate (as of July 1) - 2015 - Bo...
# 1                                               37.3
# 2                                               48.7
# 3                                               50.8
# 4                                               37.0
#
#                                  est72015sex1_medage  \
# 0  Population Estimate (as of July 1) - 2015 - Ma...
# 1                                               36.4
# 2                                               48.3
# 3                                               48.4
# 4                                               35.3
#
#                                  est72015sex2_medage  \
# 0  Population Estimate (as of July 1) - 2015 - Fe...
# 1                                               38.2
# 2                                               49.3
# 3                                               53.5
# 4                                               38.9
#
#                                  est72016sex0_medage  \
# 0  Population Estimate (as of July 1) - 2016 - Bo...
# 1                                               37.4
# 2                                               50.0
# 3                                               50.8
# 4                                               37.0
#
#                                  est72016sex1_medage  \
# 0  Population Estimate (as of July 1) - 2016 - Ma...
# 1                                               36.5
# 2                                               49.9
# 3                                               48.3
# 4                                               35.4
#
#                                  est72016sex2_medage  \
# 0  Population Estimate (as of July 1) - 2016 - Fe...
# 1                                               38.3
# 2                                               50.2
# 3                                               53.5
# 4                                               38.9
#
#                                  est72017sex0_medage  \
# 0  Population Estimate (as of July 1) - 2017 - Bo...
# 1                                               37.5
# 2                                               49.5
# 3                                               50.5
# 4                                               37.1
#
#                                  est72017sex1_medage  \
# 0  Population Estimate (as of July 1) - 2017 - Ma...
# 1                                               36.7
# 2                                               48.6
# 3                                               47.9
# 4                                               35.6
#
#                                  est72017sex2_medage
# 0  Population Estimate (as of July 1) - 2017 - Fe...
# 1                                               38.4
# 2                                               50.1
# 3                                               53.8
# 4                                               38.8
#
# [5 rows x 993 columns]

# %%
# Grab the first row for the header
new_header = dmgp_df.iloc[0]

# Take the data less the header row
dmgp_df = dmgp_df[1:]

# Set the header row as the df header
dmgp_df.columns = new_header

dmgp_df.head()
# Out:
# 0              Id    Id2                     Geography  \
# 1  0500000US06001  06001    Alameda County, California
# 2  0500000US06003  06003     Alpine County, California
# 3  0500000US06005  06005     Amador County, California
# 4  0500000US06007  06007      Butte County, California
# 5  0500000US06009  06009  Calaveras County, California
#
# 0 April 1, 2010 - Census - Both Sexes; Total  \
# 1                                    1510271
# 2                                       1175
# 3                                      38091
# 4                                     220000
# 5                                      45578
#
# 0 April 1, 2010 - Census - Male; Total April 1, 2010 - Census - Female; Total  \
# 1                               740573                                 769698
# 2                                  606                                    569
# 3                                20749                                  17342
# 4                               108931                                 111069
# 5                                22822                                  22756
#
# 0 April 1, 2010 - Estimates Base - Both Sexes; Total  \
# 1                                            1510261
# 2                                               1175
# 3                                              38091
# 4                                             220002
# 5                                              45578
#
# 0 April 1, 2010 - Estimates Base - Male; Total  \
# 1                                       740570
# 2                                          606
# 3                                        20749
# 4                                       108932
# 5                                        22822
#
# 0 April 1, 2010 - Estimates Base - Female; Total  \
# 1                                         769691
# 2                                            569
# 3                                          17342
# 4                                         111070
# 5                                          22756
#
# 0 Population Estimate (as of July 1) - 2010 - Both Sexes; Total  \
# 1                                            1513402
# 2                                               1161
# 3                                              37884
# 4                                             219957
# 5                                              45470
#
# 0                                  ...                                    \
# 1                                  ...
# 2                                  ...
# 3                                  ...
# 4                                  ...
# 5                                  ...
#
# 0 Population Estimate (as of July 1) - 2014 - Females; Median age (years)  \
# 1                                               38.1
# 2                                               47.8
# 3                                               53.1
# 4                                               38.9
# 5                                               52.4
#
# 0 Population Estimate (as of July 1) - 2015 - Both Sexes; Median age (years)  \
# 1                                               37.3
# 2                                               48.7
# 3                                               50.8
# 4                                               37.0
# 5                                               51.9
#
# 0 Population Estimate (as of July 1) - 2015 - Male; Median age (years)  \
# 1                                               36.4
# 2                                               48.3
# 3                                               48.4
# 4                                               35.3
# 5                                               50.9
#
# 0 Population Estimate (as of July 1) - 2015 - Female; Median age (years)  \
# 1                                               38.2
# 2                                               49.3
# 3                                               53.5
# 4                                               38.9
# 5                                               52.8
#
# 0 Population Estimate (as of July 1) - 2016 - Both Sexes; Median age (years)  \
# 1                                               37.4
# 2                                               50.0
# 3                                               50.8
# 4                                               37.0
# 5                                               52.0
#
# 0 Population Estimate (as of July 1) - 2016 - Male; Median age (years)  \
# 1                                               36.5
# 2                                               49.9
# 3                                               48.3
# 4                                               35.4
# 5                                               50.9
#
# 0 Population Estimate (as of July 1) - 2016 - Female; Median age (years)  \
# 1                                               38.3
# 2                                               50.2
# 3                                               53.5
# 4                                               38.9
# 5                                               53.0
#
# 0 Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)  \
# 1                                               37.5
# 2                                               49.5
# 3                                               50.5
# 4                                               37.1
# 5                                               51.9
#
# 0 Population Estimate (as of July 1) - 2017 - Male; Median age (years)  \
# 1                                               36.7
# 2                                               48.6
# 3                                               47.9
# 4                                               35.6
# 5                                               50.8
#
# 0 Population Estimate (as of July 1) - 2017 - Female; Median age (years)
# 1                                               38.4
# 2                                               50.1
# 3                                               53.8
# 4                                               38.8
# 5                                               53.0
#
# [5 rows x 993 columns]
