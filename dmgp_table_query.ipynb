# %%
# Import dependencies
import sqlite3
import pandas as pd
import numpy as np
from numpy import nan

# %%
# Connect to database
conn = sqlite3.connect('database.sqlite')

# %%
# Read sqlite query results into a pandas DataFrame
dmgp_df = pd.read_sql_query('SELECT * from demography_table',conn)
dmgp_df.head()
# Out:
#    index           Id   Id2      Geography Both_Sexes_Total_2017  \
# 0      1    0100000US  None  United States             325719178
# 1      2  0400000US01     1        Alabama               4874747
# 2      3  0400000US02     2         Alaska                739795
# 3      4  0400000US04     4        Arizona               7016270
# 4      5  0400000US05     5       Arkansas               3004279
#
#   Male_Total_2017 Female_Total_2017 Both_Sexes_Total_Under_5_years_2017  \
# 0       160408119         165311059                            19938860
# 1         2359836           2514911                              293554
# 2          386792            353003                               54083
# 3         3488301           3527969                              437262
# 4         1476064           1528215                              191435
#
#   Male_Total_Under_5_years_2017 Female_Total_Under_5_years_2017  \
# 0                      10195968                         9742892
# 1                        149374                          144180
# 2                         27625                           26458
# 3                        223615                          213647
# 4                         98313                           93122
#
#                      ...                    Female_Under_18_years_2017  \
# 0                    ...                                      36033608
# 1                    ...                                        537412
# 2                    ...                                         90011
# 3                    ...                                        800711
# 4                    ...                                        343969
#
#   Both_Sexes_Under_18_years_Under_5_years_2017  \
# 0                                     19938860
# 1                                       293554
# 2                                        54083
# 3                                       437262
# 4                                       191435
#
#   Male_Under_18_years_Under_5_years_2017  \
# 0                               10195968
# 1                                 149374
# 2                                  27625
# 3                                 223615
# 4                                  98313
#
#   Female_Under_18_years_Under_5_years_2017 Both_Sexes_18_to_64_years_2017  \
# 0                                  9742892                      201205121
# 1                                   144180                        2975503
# 2                                    26458                         472287
# 3                                   213647                        4181034
# 4                                    93122                        1799595
#
#   Male_18_to_64_years_2017 Female_18_to_64_years_2017  \
# 0                100221665                  100983456
# 1                  1451768                    1523735
# 2                   250729                     221558
# 3                  2101337                    2079697
# 4                   892266                     907329
#
#   Both_Sexes_18_to_64_years_18_to_24_years_2017  \
# 0                                      30616469
# 1                                        456229
# 2                                         72209
# 3                                        672443
# 4                                        281348
#
#   Male_18_to_64_years_18_to_24_years_2017  \
# 0                                15697044
# 1                                  230418
# 2                                   41032
# 3                                  349445
# 4                                  143391
#
#   Female_18_to_64_years_18_to_24_years_2017
# 0                                  14919425
# 1                                    225811
# 2                                     31177
# 3                                    322998
# 4                                    137957
#
# [5 rows x 73 columns]

# %%
# Save query result to csv file
dmgp_df.to_csv("clean_data\clean_demography_data.csv", sep='\t', encoding='utf-8')
