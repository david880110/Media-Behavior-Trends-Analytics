# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv("../raw_data/East Central Data/Movie Purchaser Behavior CE 2013.csv",skiprows=1)
df = pd.DataFrame(raw)
df = df.dropna().drop(['Unnamed: 1','Totals','General Movie Purchaser'], axis=1)
df
# Out:
#                                            Unnamed: 0  \
# 0                                              Totals
# 5                                         Video Game
# 10                                                 TV
# 15                                              RADIO
# 20                                           MAGAZINE
# 25                                        MOVIE GOERS
# 30                      SUPERMARKET GOER LAST 4 WEEKS
# 35                                       TABLET OWNER
# 40  All LIVE THEATER/CONCERTS/DANCE-ATTENDED LAST ...
# 45                   SOCIAL MEDIA [SOCIAL MEDIA USER]
#
#     Genral Movie Purchaser East Central  \
# 0                                 702.0
# 5                                 324.0
# 10                                631.0
# 15                                550.0
# 20                                684.0
# 25                                702.0
# 30                                694.0
# 35                                200.0
# 40                                370.0
# 45                                571.0
#
#     GenralMovie Purchaser East Central Male  \
# 0                                     295.0
# 5                                     156.0
# 10                                    258.0
# 15                                    223.0
# 20                                    288.0
# 25                                    295.0
# 30                                    293.0
# 35                                     75.0
# 40                                    137.0
# 45                                    225.0
#
#     Genral Movie Purchaser East Central Female Movie Purchaser EC 18-24  \
# 0                                        407.0                       71
# 5                                        168.0                       50
# 10                                       373.0                       53
# 15                                       327.0                       48
# 20                                       396.0                       71
# 25                                       407.0                       71
# 30                                       401.0                       69
# 35                                       125.0                       13
# 40                                       233.0                       43
# 45                                       346.0                       67
#
#    Movie Purchaser EC 18-24 male\r\n Movie Purchaser EC 18-24 Female\r\n  \
# 0                                 31                                  40
# 5                                 26                                  24
# 10                                23                                  30
# 15                                17                                  31
# 20                                31                                  40
# 25                                31                                  40
# 30                                30                                  39
# 35                                 3                                  10
# 40                                17                                  26
# 45                                29                                  38
#
#    Movie Purchaser EC 25-34 Movie Purchaser EC 25-34 male  \
# 0                       124                            51
# 5                        83                            37
# 10                      103                            38
# 15                      100                            39
# 20                      121                            49
# 25                      124                            51
# 30                      124                            51
# 35                       35                            10
# 40                       61                            21
# 45                      116                            46
#
#    Movie Purchaser EC 25-34 Female Movie Purchaser EC 35-44  \
# 0                               73                      137
# 5                               46                       84
# 10                              65                      125
# 15                              61                      108
# 20                              72                      133
# 25                              73                      137
# 30                              73                      135
# 35                              25                       49
# 40                              40                       61
# 45                              70                      117
#
#    Movie Purchaser EC 35-44 Male Movie Purchaser EC 35-44 Female  \
# 0                             71                              66
# 5                             49                              35
# 10                            63                              62
# 15                            52                              56
# 20                            69                              64
# 25                            71                              66
# 30                            71                              64
# 35                            26                              23
# 40                            27                              34
# 45                            57                              60
#
#    Movie Purchaser EC 45-54 Movie Purchaser EC 45-54 Male  \
# 0                       165                            64
# 5                        62                            31
# 10                      158                            62
# 15                      134                            53
# 20                      160                            64
# 25                      165                            64
# 30                      163                            64
# 35                       57                            21
# 40                       94                            29
# 45                      135                            51
#
#    Movie Purchaser EC 45-54 Female Movie Purchaser EC 55+  \
# 0                              101                    205
# 5                               31                     45
# 10                              96                    192
# 15                              81                    160
# 20                              96                    199
# 25                             101                    205
# 30                              99                    203
# 35                              36                     46
# 40                              65                    111
# 45                              84                    136
#
#    Movie Purchaser EC 55+ Male Movie Purchaser EC 55+ Female
# 0                           78                           127
# 5                           13                            32
# 10                          72                           120
# 15                          62                            98
# 20                          75                           124
# 25                          78                           127
# 30                          77                           126
# 35                          15                            31
# 40                          43                            68
# 45                          42                            94

# %%
list(df) # all colum names
# Out:
# ['Unnamed: 0',
#  'Genral Movie Purchaser East Central',
#  'GenralMovie Purchaser East Central Male',
#  'Genral Movie Purchaser East Central Female',
#  'Movie Purchaser EC 18-24',
#  'Movie Purchaser EC 18-24 male\r\n',
#  'Movie Purchaser EC 18-24 Female\r\n',
#  'Movie Purchaser EC 25-34',
#  'Movie Purchaser EC 25-34 male',
#  'Movie Purchaser EC 25-34 Female',
#  'Movie Purchaser EC 35-44',
#  'Movie Purchaser EC 35-44 Male',
#  'Movie Purchaser EC 35-44 Female',
#  'Movie Purchaser EC 45-54',
#  'Movie Purchaser EC 45-54 Male',
#  'Movie Purchaser EC 45-54 Female',
#  'Movie Purchaser EC 55+',
#  'Movie Purchaser EC 55+ Male',
#  'Movie Purchaser EC 55+ Female']

# %%
# replace ' ' in category names with "_"
cat = list(i.strip().replace(' ','_') for i in list(df['Unnamed: 0']))
cat
# Out:
# ['Totals',
#  'Video_Game',
#  'TV',
#  'RADIO',
#  'MAGAZINE',
#  'MOVIE_GOERS',
#  'SUPERMARKET_GOER_LAST_4_WEEKS',
#  'TABLET_OWNER',
#  'All_LIVE_THEATER/CONCERTS/DANCE-ATTENDED_LAST_12_MONTHS',
#  'SOCIAL_MEDIA_[SOCIAL_MEDIA_USER]']

# %%
# # Create a reference for Female and Male Population at each age zone and category
# dict_GM = dict()
# # dict_GM['Total'] = list(df['Genral Movie Purchaser East Central'])
# # dict_GM['GM_Male'] = list(df['GenralMovie Purchaser East Central Male'])
# # dict_GM['GM_Female'] = list(df['GenralMovie Purchaser East Central Female'])
# # dict_GM['18-24'] = list(df['Movie Purchaser EC 18-24'])
# # dict_GM['25-34'] = list(df['Movie Purchaser EC 25-34'])
# # dict_GM['35-44'] = list(df['Movie Purchaser EC 35-44'])
# # dict_GM['45-54'] = list(df['Movie Purchaser EC 45-54'])
# # dict_GM['55+'] = list(df['Movie Purchaser EC 55+'])
# keys = ['18-24_f', '18-24_m', '25-34_f', '25-34_m', '35-44_f', '35-44_m', '45-54_f', '45-54_m', '55_f', '55_m']
# columns = ['Movie Purchaser EC 18-24 Female\r\n','Movie Purchaser EC 18-24 male\r\n','Movie Purchaser EC 25-34 Female'\
#           ,'Movie Purchaser EC 25-34 male','Movie Purchaser EC 35-44 Female','Movie Purchaser EC 35-44 Male'\
#           ,'Movie Purchaser EC 45-54 Female','Movie Purchaser EC 45-54 Male','Movie Purchaser EC 55+ Female'\
#           ,'Movie Purchaser EC 55+ Male']
# for i in range(0,len(list(keys))):
#     dict_GM[keys[i]] = list(df[columns[i]].astype('int64'))
# dict_GM

# %%
# population for each category
pop_list = []
for index, row in df.iterrows():
    pop_list += [int(row['Movie Purchaser EC 18-24 male\r\n'])] + [int(row['Movie Purchaser EC 25-34 male'])]\
                + [int(row['Movie Purchaser EC 35-44 Male'])] + [int(row['Movie Purchaser EC 45-54 Male'])]\
                + [int(row['Movie Purchaser EC 55+ Male'])]+ [int(row['Movie Purchaser EC 18-24 Female\r\n'])]\
                +  [int(row['Movie Purchaser EC 25-34 Female'])] + [int(row['Movie Purchaser EC 35-44 Female'])]\
                + [int(row['Movie Purchaser EC 45-54 Female'])]+ [int(row['Movie Purchaser EC 55+ Female'])]
pop_list
# Out:
# [31,
#  51,
#  71,
#  64,
#  78,
#  40,
#  73,
#  66,
#  101,
#  127,
#  26,
#  37,
#  49,
#  31,
#  13,
#  24,
#  46,
#  35,
#  31,
#  32,
#  23,
#  38,
#  63,
#  62,
#  72,
#  30,
#  65,
#  62,
#  96,
#  120,
#  17,
#  39,
#  52,
#  53,
#  62,
#  31,
#  61,
#  56,
#  81,
#  98,
#  31,
#  49,
#  69,
#  64,
#  75,
#  40,
#  72,
#  64,
#  96,
#  124,
#  31,
#  51,
#  71,
#  64,
#  78,
#  40,
#  73,
#  66,
#  101,
#  127,
#  30,
#  51,
#  71,
#  64,
#  77,
#  39,
#  73,
#  64,
#  99,
#  126,
#  3,
#  10,
#  26,
#  21,
#  15,
#  10,
#  25,
#  23,
#  36,
#  31,
#  17,
#  21,
#  27,
#  29,
#  43,
#  26,
#  40,
#  34,
#  65,
#  68,
#  29,
#  46,
#  57,
#  51,
#  42,
#  38,
#  70,
#  60,
#  84,
#  94]

# %%
# clean data table
clean_df = pd.DataFrame(columns=['Cat','Gender','Age','Year','Region','Pop'])
cat_list = []
for i in cat:
    cat_list += [i]*10
clean_df["Cat"] = cat_list
clean_df['Gender'] = (['Male']*5+['Female']*5)*len(cat)
clean_df['Age'] = ['28-24','25-34','35-44','45-54','55+']*2*len(cat)
clean_df['Year'] = [2013]*len(cat)*10
clean_df['Region'] = ['Central East']*len(cat)*10
clean_df['Pop'] = pop_list
clean_df
# Out:
#                                                   Cat  Gender    Age  Year  \
# 0                                              Totals    Male  28-24  2013
# 1                                              Totals    Male  25-34  2013
# 2                                              Totals    Male  35-44  2013
# 3                                              Totals    Male  45-54  2013
# 4                                              Totals    Male    55+  2013
# 5                                              Totals  Female  28-24  2013
# 6                                              Totals  Female  25-34  2013
# 7                                              Totals  Female  35-44  2013
# 8                                              Totals  Female  45-54  2013
# 9                                              Totals  Female    55+  2013
# 10                                         Video_Game    Male  28-24  2013
# 11                                         Video_Game    Male  25-34  2013
# 12                                         Video_Game    Male  35-44  2013
# 13                                         Video_Game    Male  45-54  2013
# 14                                         Video_Game    Male    55+  2013
# 15                                         Video_Game  Female  28-24  2013
# 16                                         Video_Game  Female  25-34  2013
# 17                                         Video_Game  Female  35-44  2013
# 18                                         Video_Game  Female  45-54  2013
# 19                                         Video_Game  Female    55+  2013
